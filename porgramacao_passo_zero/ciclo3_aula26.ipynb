# %%
#Importando o arquivo
import pandas as pd
import io
df = pd.read_csv(r'/Users/fernanda/Documents/repos/ftc/arquivos_baixados/train.csv')
df1 = df.copy()

# %%
#1
df1.iloc[30, 10]
# Out:
# '22:40:00'

# %%
#2 
df1.iloc[0:20, 0:2]
# Out:
#          ID Delivery_person_ID
# 0   0x4607     INDORES13DEL02
# 1   0xb379     BANGRES18DEL02
# 2   0x5d6d     BANGRES19DEL01
# 3   0x7a6a    COIMBRES13DEL02
# 4   0x70a2     CHENRES12DEL01
# 5   0x9bb4      HYDRES09DEL03
# 6   0x95b4   RANCHIRES15DEL01
# 7   0x9eb2      MYSRES15DEL02
# 8   0x1102      HYDRES05DEL02
# 9   0xcdcd      DEHRES17DEL01
# 10  0xd987      KOCRES16DEL01
# 11  0x2784     PUNERES13DEL03
# 12  0xc8b6     LUDHRES15DEL02
# 13  0xdb64      KNPRES14DEL02
# 14  0x3af3      MUMRES15DEL03
# 15  0x3aab      MYSRES01DEL01
# 16  0x689b     PUNERES20DEL01
# 17  0x6f67      HYDRES14DEL01
# 18  0xc9cf      KOLRES15DEL03
# 19  0x36b8     PUNERES19DEL02

# %%
#3
df1.loc[5:30, 'Delivery_person_Age']
# Out:
# 5     22
# 6     33
# 7     35
# 8     22
# 9     36
# 10    21
# 11    23
# 12    34
# 13    24
# 14    29
# 15    35
# 16    33
# 17    34
# 18    21
# 19    25
# 20    31
# 21    37
# 22    33
# 23    25
# 24    29
# 25    27
# 26    35
# 27    32
# 28    23
# 29    31
# 30    36
# Name: Delivery_person_Age, dtype: object

# %%
#4
colunas = 'Restaurant_latitude',
'Restaurant_longitude', 'Delivery_location_latitude',
'Delivery_location_longitude'

df1.loc[40:42, colunas]
# Out:
#     Restaurant_latitude
# 40            12.972532
# 41            13.064181
# 42            19.121999

# %%
#5
df_1 = df1.loc[0:50]
df_2 = df_1.sort_values(by='Order_Date', ascending=True)
df_2
# Out:
#          ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 15  0x3aab      MYSRES01DEL01                   35                       4
# 38  0x4bda      HYDRES17DEL02                   35                       5
# 29  0x3e60    COIMBRES02DEL03                   31                     4.8
# 34  0x30c8     PUNERES19DEL02                   32                     4.6
# 28  0x3c5e     PUNERES04DEL01                   23                     4.8
# 14  0x3af3      MUMRES15DEL03                   29                     4.5
# 50  0x5554   RANCHIRES15DEL01                   31                     4.9
# 36  0xb3a0     PUNERES18DEL01                   20                     4.7
# 6   0x95b4   RANCHIRES15DEL01                   33                     4.7
# 11  0x2784     PUNERES13DEL03                   23                     4.7
# 43  0xb796      SURRES17DEL03                   37                     4.7
# ...

# %%
#6
df_1 = df1.loc[0:50]
df_2 = df_1.sort_values(by='Time_Orderd', ascending=True)
df_2
# Out:
#          ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 21  0x6c6b    COIMBRES13DEL01                   37                       5
# 2   0x5d6d     BANGRES19DEL01                   23                     4.4
# 39  0x9d26     BANGRES17DEL02                   26                     4.9
# 12  0xc8b6     LUDHRES15DEL02                   34                     4.3
# 38  0x4bda      HYDRES17DEL02                   35                       5
# 45  0xc644      KOLRES16DEL02                   37                     4.9
# 37  0x6531      SURRES08DEL01                   20                     4.8
# 0   0x4607     INDORES13DEL02                   37                     4.9
# 49  0x3556      SURRES09DEL01                   33                       5
# 23  0x539b      MUMRES02DEL01                   25                       4
# 4   0x70a2     CHENRES12DEL01                   32                     4.6
# ...

# %%
#7
df_1 = df1.iloc[50:70]
df_2 = df1['City'].unique()
df_2
# Out:
# array(['Urban ', 'Metropolitian ', 'Semi-Urban ', 'NaN '], dtype=object)

# %%
#8
df_1 = df1.iloc[0:10]
df_2 = df1['Weatherconditions'].unique()
df_2
# Out:
# array(['conditions Sunny', 'conditions Stormy', 'conditions Sandstorms',
#        'conditions Cloudy', 'conditions Fog', 'conditions Windy',
#        'conditions NaN'], dtype=object)

# %%
#9
df_1 = df1.iloc[0:20]
df_2 = df_1['Road_traffic_density'].unique()
df_2
# Out:
# array(['High ', 'Jam ', 'Low ', 'Medium '], dtype=object)

# %%
#10
df_1 = df1.iloc[50:70]
df_2 = df_1.sort_values(by='Delivery_person_Age', ascending=False)
df_2
# Out:
#          ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 69  0xa258     CHENRES12DEL03                   39                     4.6
# 66  0xde72      DEHRES19DEL02                   39                     4.9
# 56  0xddc5      AGRRES12DEL03                   39                     4.6
# 57  0x8e6c      VADRES02DEL02                   39                     4.2
# 64  0x1609     PUNERES02DEL01                   36                     4.9
# 59  0x395b      VADRES04DEL03                   36                     4.7
# 68  0x273a      VADRES09DEL01                   35                     4.8
# 61  0xb55a      MYSRES04DEL03                   33                     4.9
# 63  0xbe80      MUMRES04DEL01                   33                       5
# 58  0xb002      JAPRES14DEL01                   32                     4.5
# 50  0x5554   RANCHIRES15DEL01                   31                     4.9
# ...

# %%
df_1.head(2)
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  19-03-2022    11:30:00          11:45:00
# 1                    77.813237  25-03-2022    19:45:00          19:50:00
#
#    Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0   conditions Sunny                High                   2        Snack
# 1  conditions Stormy                 Jam                   2        Snack
#
# ...

# %%
#11
df_1 = df1.iloc[50:70]
df_2 = df_1.sort_values(by='Delivery_person_Ratings', ascending=False)
df_2
# Out:
#          ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 52  0xc1ff     AURGRES20DEL03                   25                       5
# 63  0xbe80      MUMRES04DEL01                   33                       5
# 50  0x5554   RANCHIRES15DEL01                   31                     4.9
# 66  0xde72      DEHRES19DEL02                   39                     4.9
# 64  0x1609     PUNERES02DEL01                   36                     4.9
# 61  0xb55a      MYSRES04DEL03                   33                     4.9
# 51  0x25fd     BANGRES19DEL01                   31                     4.8
# 68  0x273a      VADRES09DEL01                   35                     4.8
# 67  0x98aa      VADRES16DEL02                   23                     4.8
# 65  0xd255      ALHRES07DEL02                   21                     4.8
# 60  0x8aa2      JAPRES18DEL02                   25                     4.8
# ...

# %%
#12
df_1 = df1.iloc[0:30]
df_2 = df_1['Type_of_vehicle'].unique()
df_2
# Out:
# array(['motorcycle ', 'scooter ', 'electric_scooter '], dtype=object)

# %%
#13
df_1 = df1.iloc[100:120]
df_2 = df_1['Type_of_order'].unique()
df_2
# Out:
# array(['Snack ', 'Meal ', 'Buffet ', 'Drinks '], dtype=object)
